-- %%
-- To selct all data from catalog.schema.table
select * from codebasics.fundamental.movies;

-- Select movie where release year is greater than 2009
select count(*) as total_movie from codebasics.fundamental.movies where release_year > 2009;

select count(*) as movie from codebasics.fundamental.movies group by release_year;
